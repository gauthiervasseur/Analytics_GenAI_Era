# %% [markdown]
# # Install these first - Python 3.12.4 compatible

# %%
pip install --upgrade pip

# %%
pip install ydata_profiling

# %%
pip install --upgrade jinja2

# %%
pip install --upgrade markupsafe

# %%
pip install dataprep

# %%
pip install bokeh

# %%
pip install dtale

# %%
pip install autoviz

# %%
pip install sweetviz

# %%
pip install ipywidgets

# %% [markdown]
# # Run from this box - Python 3.12.4 compatible

# %%
# Define the file path
file_path = 'data/Melbourne_housing.csv'

# %% [markdown]
# # YData Profiling

# %%
#Install the below libaries before importing
import pandas as pd
import pkg_resources
from ydata_profiling import ProfileReport

profile = ProfileReport(pd.read_csv(file_path), title="Your Dataset Report", explorative=True, correlations={
    "pearson": {"calculate": True},
    "spearman": {"calculate": True},
    "kendall": {"calculate": True},
    "phi_k": {"calculate": True},
    "cramers": {"calculate": True}
})

#EDA using pandas-profiling
# profile = ProfileReport(pd.read_csv(file_path), explorative=True)

#Saving results to a HTML file
profile.to_file("seoul_profile.html")

# Display the report inline in a Jupyter Notebook
profile.to_notebook_iframe()
# Out:
# ...
# 100%|██████████| 21/21 [00:00<00:00, 56.38it/s]
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ...

# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 8.4 MB/s  0:00:01 eta 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 7.9 MB/s  0:00:00 eta 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [numpy]  WARNING: The scripts f2py and numpy-config are installed in '/Library/Frameworks/Python.framework/Versions/3.14/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ydata_profiling
# Out:
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# ...
#   Using cached dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...

# %%
pip install --upgrade setuptools
# Out:
# ...
#   Using cached setuptools-82.0.0-py3-none-any.whl.metadata (6.6 kB)
# Using cached setuptools-82.0.0-py3-none-any.whl (1.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda env list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'env list')
#
# File ~/Library/Python/3.13/lib/python/site-packages/IPython/core/interactiveshell.py:2511, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2509     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2510 with self.builtin_trap:
# -> 2511     result = fn(*args, **kwargs)
#    2513 # The code below prevents the output from being displayed
#    2514 # when using magics with decorator @output_can_be_silenced
#    2515 # when the last Python token in the expression is a ';'.
#    2516 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Library/Python/3.13/lib/python/site-packages/IPython/core/magics/packaging.py:27, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
# ...

# %% [markdown]
# # Dtale Analysis and Profiling

# %%
import dtale
import pandas as pd
dtale.show(pd.read_csv(file_path))

# Start D-Tale server and open in browser
d = dtale.show(pd.read_csv(file_path))
d.open_browser()

# %% [markdown]
# # SweetViz Profiling

# %%
import pandas as pd
import sweetviz as sv

#EDA using Autoviz
sweet_report = sv.analyze(pd.read_csv(file_path))

#Sending results to HTML file
sweet_report.show_html()

#Saving results to HTML file
sweet_report.show_html('sweet_report.html')
